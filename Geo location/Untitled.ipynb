# %%
# !pip3 install geopandas
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pycountry
import geopandas as gpd
#import re
# Out:
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\ProgramData\Anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\basha\\AppData\\Local\\Temp\\pip-install-2exsf7ie\\fiona_de0f70fb83404fed884aa0007fb8a19f\\setup.py'"'"'; __file__='"'"'C:\\Users\\basha\\AppData\\Local\\Temp\\pip-install-2exsf7ie\\fiona_de0f70fb83404fed884aa0007fb8a19f\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\basha\AppData\Local\Temp\pip-pip-egg-info-9_7kgp5y'
#          cwd: C:\Users\basha\AppData\Local\Temp\pip-install-2exsf7ie\fiona_de0f70fb83404fed884aa0007fb8a19f\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
# ...
